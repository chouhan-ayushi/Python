# %%
print("hiiiii")
# Out:
# hiiiii

# %%
import pandas as pd
#help(pd.series)
myindex=["INDORE","BHOPAL","NOIDA"]
mydata=[1500,800,12]
myseries=pd.Series(data=mydata,index=myindex)
myseries
# Out:
# INDORE    1500
# BHOPAL     800
# NOIDA       12
# dtype: int64

# %%
import pandas as pd
myindex=["Name","Age","City"]
mydata=["Ram",23,"Bhopal"]
myseries=pd.Series(data=mydata,index=myindex)
myseries
# Out:
# Name       Ram
# Age         23
# City    Bhopal
# dtype: object

# %%
import pandas as pd
myindex=["Student 1","Student 2","Student 3","Student4"]
mydata = {'Name': ['Anurag', 'Jansi', 'Maheshireen', 'Ella'],
        'Age': ["M","F","F","Error"]}
myseries=pd.DataFrame(data=mydata,index=myindex)
myseries
# Out:
#                   Name    Age
# Student 1       Anurag      M
# Student 2        Jansi      F
# Student 3  Maheshireen      F
# Student4          Ella  Error

# %%
import pandas as pd
data = {'Name': ['sonal', 'nikhil', 'sara', 'ayushi'],
        'Age': [20, 21, 19, 18],'city':['Indore','Bhopal','Betul','Gwalior']}
myseries=pd.DataFrame(data)
myseries
# Out:
#      Name  Age     city
# 0   sonal   20   Indore
# 1  nikhil   21   Bhopal
# 2    sara   19    Betul
# 3  ayushi   18  Gwalior
